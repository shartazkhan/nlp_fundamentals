# %% [markdown]
# <a href="https://colab.research.google.com/github/shartazkhan/nlp_fundamentals/blob/main/NLP_Text_Preprocessing_2_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What we will do here
#
#
# 1.   Create a custom dataset from scrach.
# 2.   Apply data preprocessing on it
#
#
# We will create a movie dataset with **3** columns,
#
# **1) Movie name, 2) Description** and 3) **Genre**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# # 1. Data scraping to create dataset

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=8c687e4428d8187418aaf8d96c75de17&language=en-US&with_original_language=bn')

response
# Out:
# <Response [200]>

# %%
for page in range(1,188):
    link = f'https://api.themoviedb.org/3/discover/movie?api_key=8c687e4428d8187418aaf8d96c75de17&language=en-US&with_original_language=bn&page={page}'
    response = requests.get(link)
    temp_df = pd.DataFrame(response.json()['results']).head()[['id','title','overview','genre_ids','adult']]
    temp_df
    # df = df.append(temp_df,ignore_index=True)
    df=pd.concat([df,temp_df],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3109896517.py in <cell line: 0>()
#       5     temp_df
#       6     # df = df.append(temp_df,ignore_index=True)
# ----> 7     df=pd.concat([df,temp_df],ignore_index=True)
#
# NameError: name 'df' is not defined

# %%
df.sample(5)

# %%
if df is not None:
    df.to_csv('tmdb_bengali_content.csv', index=False)
    print("DataFrame saved to bengali_movies.csv")
else:
    print("No DataFrame to save.")

# %% [markdown]
# # 2. I call it pre-preporcessing

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Bangla Movie 2k imdb/bangla_movies_imdb_2k.csv')

# %%
df.sample(5)
# Out:
#       year run_time                                  short_description  \
# 1187  2000   2h 16m  A landlord and his son are untouchable by the ...
# 1214  1999   2h 30m  The second movie directed by Humayun Ahmed. A ...
# 957   2009   2h 18m                                                NaN
# 1590  1982   2h 24m  Two childhood sweethearts departs from each ot...
# 889   2012      NaN                       A story of king and kingdom.
#
#       rating rating_count  genre               name
# 1187     8.6         (15)  drama              Golam
# 1214     8.6       (2.8K)  drama  Srabon Megher Din
# 957      6.5         (24)  drama   Chander Moto Bou
# 1590     7.5         (27)  drama             Devdas
# 889      NaN          NaN  drama     Raja Surja Kha

# %%
len(df)
# Out:
# 2000

# %%
df = df[['name', 'genre', 'short_description']]
display(df.head())
# Out:
#                 name                      genre  \
# 0         Abar Jaago                      drama
# 1  Mrucha Chiasodpoi                documentary
# 2            Borbaad  action, romance, thriller
# 3            Taandob           action, thriller
# 4             Jongli                      drama
#
#                                    short_description
# 0  A national star cricketer Hasan Ahsan gets ban...
# 1  In the remote hills of the Chittagong Hill Tra...
# 2  After a heartbreak by Nitu, Ariyan Mirza seeks...
# 3  A jobless villager moves to Dhaka for work but...
# 4  A troubled university student, haunted by fami...

# %%
df['short_description'][49]
# Out:
# nan

# %%
df.dropna(subset=['short_description'], inplace=True)
df.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipython-input-1429314726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['short_description'], inplace=True)

# %%
len(df)
# Out:
# 883

# %%
df['short_description'][49]
# Out:
# "Asif joins neighborhood cricket led by skilled batter Mahtab. They nickname a pretty woman 'Sania Mirza', sparking rumours of her being Mahtab's girlfriend. But when Asif meets her unexpectedly, a shocking truth comes to light."

# %% [markdown]
# # 3. Preprocessing (Real one)

# %% [markdown]
# 1.   Convert data to lowercase
# 2.   Remove unnecessery things
# 3.   Chat word Treatment (if needed)
# 4.   Spell check
# 5.   Stopwords check
# 6.   Handling Emojis
# 7.   Tokenization
# 8.   Stemming / Lemmatization

# %% [markdown]
# ## 1. Convert data to lowercase

# %%
df.loc[:, 'short_description'] = df['short_description'].str.lower()

display(df.sample(5))
# Out:
#                              name    genre  \
# 587                   Swopnodanay    drama
# 220                 Rickshaw Girl    drama
# 314                Buker Ba Pashe    drama
# 71   Mr. Engineer and Miss Doctor  romance
# 192                        Scooty    drama
#
#                                      short_description
# 587  a poor villager finds some high priced foreign...
# 220  a daring bangladeshi teenager attempts to help...
# 314  in a bus journey, two people share two seats n...
# 71   when engineer nihaal crosses paths with doctor...
# 192  anu bahar, a girl from a middle class family, ...

# %%
df['short_description'][49]
# Out:
# "asif joins neighborhood cricket led by skilled batter mahtab. they nickname a pretty woman 'sania mirza', sparking rumours of her being mahtab's girlfriend. but when asif meets her unexpectedly, a shocking truth comes to light."

# %% [markdown]
# ## 2.   Remove unnecessery things

# %% [markdown]
# Remove HTML tags (if any)

# %%
import re

def remove_html_tags(text):
    clean = re.compile('<.*?>')
    return clean.sub(r'', str(text)) # Convert to string before applying regex

df.loc[:,'short_description'] = df['short_description'].astype(str).apply(remove_html_tags)

# %%
df['short_description'][49]
# Out:
# "asif joins neighborhood cricket led by skilled batter mahtab. they nickname a pretty woman 'sania mirza', sparking rumours of her being mahtab's girlfriend. but when asif meets her unexpectedly, a shocking truth comes to light."

# %% [markdown]
# Remove URLs

# %%
def remove_url(text):
    clean = re.compile('https?://\S+|www\.\S+')
    return clean.sub(r'', text)

df.loc[:,'short_description'] = df['short_description'].apply(remove_url)

display(df.sample(5))
# Out:
#                         name        genre  \
# 63             Tokhon Jokhon        drama
# 381                    Rokto       action
# 622  Teardrops of Karnaphuli  documentary
# 121                     Pori          NaN
# 820              Ononto Prem        drama
#
#                                      short_description
# 63   raha and tanim wanted to get married and both ...
# 381  it is loosely based on the long kiss goodnight...
# 622  a documentary film on the plight of the indige...
# 121  puja chery is portraying the central character...
# 820  a young man who wants to help his friend in lo...

# %%
df['short_description'][43]
# Out:
# 'three interconnected romantic stories unfold, delving into the intricacies of love, passion, and heartbreak.'

# %% [markdown]
# Remove Punctuations

# %%
import string

def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)

    return text.translate(translator)

df.loc[:,'short_description'] = df['short_description'].apply(remove_punctuation)


display(df.sample(5))
# Out:
#                   name    genre  \
# 366           Chitkini    drama
# 850      Sadharon Meye    drama
# 793              Nazma    drama
# 54   Thikana Bodle Jay  romance
# 247        August 1975  history
#
#                                      short_description
# 366  panchagarh rail station of north bangladesh is...
# 850             a story of a simple college going girl
# 793  a wifes love and integrity towards her husband...
# 54   after completing his masters he is applying fo...
# 247  the film portrays the initial events of the ra...

# %%
df['short_description'][49]
# Out:
# 'asif joins neighborhood cricket led by skilled batter mahtab they nickname a pretty woman sania mirza sparking rumours of her being mahtabs girlfriend but when asif meets her unexpectedly a shocking truth comes to light'

# %% [markdown]
# ## 3.   Chat word Treatment (if needed)

# %%
file_path = '/content/drive/MyDrive/Datasets/chat_words_dictionary.txt'

try:
    with open(file_path, 'r') as f:
        file_content = f.read()

        chat_words_dict = {}
        for line in file_content.strip().split('\n'):
            if '=' in line:
                abbr, full_form = line.split('=', 1)
                chat_words_dict[abbr.strip()] = full_form.strip()

        print("\nChat word dictionary created:")
        display(chat_words_dict)

except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Chat word dictionary created:
# {'afaik': 'as far as i know',
#  'afk': 'away from keyboard',
#  'asap': 'as soon as possible',
#  'atk': 'at the keyboard',
#  'atm': 'at the moment',
#  'a3': 'anytime anywhere anyplace',
#  'bak': 'back at keyboard',
#  'bbl': 'be back later',
#  'bbs': 'be back soon',
#  'bfn': 'bye for now',
#  'brb': 'be right back',
#  'brt': 'be right there',
#  'btw': 'by the way',
#  'b4': 'before',
#  'cu': 'see you',
#  'cul8r': 'see you later',
#  'faq': 'frequently asked questions',
#  'fc': 'fingers crossed',
#  'fwiw': 'for what its worth',
#  'fyi': 'for your information',
#  'gal': 'get a life',
#  'gg': 'good game',
#  'gn': 'good night',
#  'gday': 'good day',
#  'gmta': 'great minds think alike',
#  'gr8': 'great',
#  'g9': 'genius',
#  'iykyk': 'if you know you know',
#  'ic': 'i see',
#  'icq': 'i seek you also a chat program',
#  'ilu': 'ilu i love you',
#  'imho': 'in my honesthumble opinion',
#  'imo': 'in my opinion',
#  'iow': 'in other words',
#  'irl': 'in real life',
#  'kiss': 'keep it simple stupid',
#  'ldr': 'long distance relationship',
#  'lmao': 'laughing my ass off',
#  'lol': 'laughing out loud',
#  'ltns': 'long time no see',
#  'l8r': 'later',
#  'mte': 'my thoughts exactly',
#  'm8': 'mate',
#  'nrn': 'no reply necessary',
#  'oic': 'oh i see',
#  'pita': 'pain in the ass',
#  'prt': 'party',
#  'prw': 'parents are watching',
#  'qpsa': 'que pasa',
#  'rofl': 'rolling on the floor laughing',
#  'roflol': 'rolling on the floor laughing out loud',
#  'rotflmao': 'rolling on the floor laughing my ass off',
#  'sk8': 'skate',
#  'stats': 'your sex and age',
#  'asl': 'age sex location',
#  'thx': 'thank you',
#  'ttfn': 'tata for now',
#  'ttyl': 'talk to you later',
#  'u': 'you',
#  'u2': 'you too',
#  'u4e': 'yours for ever',
#  'wb': 'welcome back',
#  'wtf': 'what the fuck',
#  'wtg': 'way to go',
#  'wuf': 'where are you from',
#  'w8': 'wait',
#  'tfw': 'that feeling when',
#  'mfw': 'my face when',
#  'mrw': 'my reaction when',
#  'ifyp': 'i feel your pain',
#  'tntl': 'trying not to laugh',
#  'jk': 'just kidding',
#  'idc': 'i don’t care',
#  'ily': 'i love you',
#  'imu': 'i miss you',
#  'adih': 'another day in hell',
#  'zzz': 'sleeping bored tired',
#  'wywh': 'wish you were here',
#  'time': 'tears in my eyes',
#  'bae': 'before anyone else',
#  'fimh': 'forever in my heart',
#  'bsaaw': 'big smile and a wink',
#  'bwl': 'bursting with laughter',
#  'csl': 'can’t stop laughing',
#  'sry': 'sorry'}

# %% [markdown]
# We don't need this here. If we were working with reviews this could be helpful.

# %% [markdown]
# ## 4.   Spell check

# %% [markdown]
# We also don't need this in this dataset. If we were working with reviews this could be helpful.

# %%
# !pip install autocorrect

from autocorrect import Speller

spell = Speller(lang='en')

df['short_description'] = df['short_description'].apply(spell)

display(df.sample(5))
# Out:
#                       name      genre  \
# 473              Boishommo      drama
# 63           Tokhon Jokhon      drama
# 48              Gyani Goni     family
# 97              Puff Daddy      drama
# 256  I'm Fine Fake Friends  biography
#
#                                      short_description
# 473  presents the young vibrant architecture scene ...
# 63   raja and anim wanted to get married and both o...
# 48   gone a village auto mechanic is known far and ...
# 97   supernatural gifted fortune teller puff daddy ...
# 256  the story begins with a girl and a boy a girl ...

# %% [markdown]
# ## 5.   Stopwords Remove

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
def remove_stopwords(text):
    new_text = []

    for word in text.split():
        if word in stopwords.words('english'):
            new_text.append('')
        else:
            new_text.append(word)
    return " ".join(new_text)

# %%
df['short_description'] = df['short_description'].apply(remove_stopwords)

display(df.sample(5))
# Out:
#                      name   genre  \
# 97             Puff Daddy   drama
# 801  Emiler Goenda Bahini  comedy
# 508           Uttarer Sur   drama
# 781           Ma o Chhele   drama
# 779                 Dahan   drama
#
#                                      short_description
# 97   supernatural gifted fortune teller puff daddy ...
# 801    boy   widow went   train trip  dhaka  receiv...
# 508  life story   street singer   little daughter  ...
# 781   son takes revenge   insult   mother   uncle  ...
# 779  struggle   lower middle class family   militar...

# %% [markdown]
# ## 6.   Handling Emojis

# %%
# We don't need to

# %% [markdown]
# ## 7.   Tokenization

# %%
from nltk import word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['short_description'] = df['short_description'].apply(word_tokenize)

display(df.head())
# Out:
#                 name                      genre  \
# 0         Abar Jaago                      drama
# 1  Mrucha Chiasodpoi                documentary
# 2            Borbaad  action, romance, thriller
# 3            Taandob           action, thriller
# 4             Jongli                      drama
#
#                                    short_description
# 0  [national, star, cricketer, hasan, hasan, gets...
# 1  [remote, hills, chittagong, hill, tracts, bang...
# 2  [heartbreak, situ, asian, mira, seeks, revenge...
# 3  [nobles, villager, moves, dhaka, work, gets, e...
# 4  [troubled, university, student, haunted, famil...

# %% [markdown]
# ## 8.   Stemming / Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('wordnet')

wordnet_lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download('wordnet')

wordnet_lemmatizer = WordNetLemmatizer()

def lemmatize_words(word_list):
  return [wordnet_lemmatizer.lemmatize(word) for word in word_list]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df['short_description'] = df['short_description'].apply(lemmatize_words)

display(df.head())
# Out:
#                 name                      genre  \
# 0         Abar Jaago                      drama
# 1  Mrucha Chiasodpoi                documentary
# 2            Borbaad  action, romance, thriller
# 3            Taandob           action, thriller
# 4             Jongli                      drama
#
#                                    short_description
# 0  [national, star, cricketer, hasan, hasan, get,...
# 1  [remote, hill, chittagong, hill, tract, bangla...
# 2  [heartbreak, situ, asian, mira, seek, revenge,...
# 3  [noble, villager, move, dhaka, work, get, enta...
# 4  [troubled, university, student, haunted, famil...

# %%
df['short_description'][56]
# Out:
# ['young',
#  'girl',
#  'mother',
#  'go',
#  'middle',
#  'east',
#  'migration',
#  'work',
#  'disappears',
#  'confronted',
#  'unendurable',
#  'circumstance',
#  'eviction',
#  'overdue',
#  'tuition',
#  'grocery',
#  'ultimatum',
#  'force',
#  'become',
#  'house',
#  'maid']
